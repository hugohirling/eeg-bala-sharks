# %% [markdown]
# # Sanity Check
# ## 00 - load data per person
# ## 01 - re-referencing

# %%
import pandas as pd
from pathlib import Path

tsv_dir = Path('../MNE-sample-data/ds006761/sub-01')
tsv_file = next(tsv_dir.glob('**/*.tsv'), None)

print(tsv_file)

df = pd.read_csv(tsv_file, sep='\t')
df.head()
# Out:
# ..\MNE-sample-data\ds006761\sub-01\eeg\sub-01_task-RPS_events.tsv
#        onset  duration  onset_sample  trial_num  player1_resp  player1_rt  \
# 0  32.777344         5         67128          1             3       0.558
# 1  37.769043         5         77351          2             3       0.435
# 2  42.760742         5         87574          3             2       0.643
# 3  47.760254         5         97813          4             2       0.717
# 4  52.760254         5        108053          5             1       0.642
#
#    player2_resp  player2_rt  outcome
# 0             2       0.516        2
# 1             3       0.560        1
# 2             2       0.451        1
# 3             2       0.459        1
# 4             3       0.359        2

# %%
import mne
import numpy as np
from pathlib import Path
import sys

# Pipeline config importieren
PIPELINE_PATH = Path("../eeg_pipeline")
if PIPELINE_PATH not in sys.path:
    sys.path.insert(0, str(PIPELINE_PATH))
import config

# --- Lade die Daten ---
SUBJECT = config.SUBJECTS[0]  # z.B. "01"
PERSON = "P1"                  # "P1" oder "P2"

raw_path = config.OUTPUT_DIR / f"sub-{SUBJECT}_{PERSON}_raw.fif"
print(f"Loading: {raw_path}")

raw = mne.io.read_raw_fif(raw_path, preload=True)
print("✅ Raw data loaded.\n")

# Nur EEG-Kanäle auswählen
raw_eeg = raw.copy().pick_types(eeg=True)

# Präfix entfernen (z.B. "1-A1" -> "A1")
prefix = "1-"
mapping_prefix = {ch: ch[len(prefix):] for ch in raw_eeg.ch_names if ch.startswith(prefix)}
raw_eeg.rename_channels(mapping_prefix)

# -----------------------------------------
# 🔥 BioSemi64 → Standard-10–20 Mapping
# -----------------------------------------


bios64_to_1020 = {
    # A row
    "A1": "Fp1", "A2": "AF7", "A3": "AF3", "A4": "F1", "A5": "F3",
    "A6": "F5", "A7": "F7", "A8": "FT7", "A9": "FC5", "A10": "FC3",
    "A11": "FC1", "A12": "C1", "A13": "C3", "A14": "C5", "A15": "T7",
    "A16": "TP7", "A17": "CP5", "A18": "CP3", "A19": "CP1", "A20": "P1",
    "A21": "P3", "A22": "P5", "A23": "P7", "A24": "P9", "A25": "PO7",
    "A26": "PO3", "A27": "O1", "A28": "Iz", "A29": "Oz", "A30": "POz",
    "A31": "Pz", "A32": "CPz",

    # B row
    "B1": "Fpz", "B2": "Fp2", "B3": "AF8", "B4": "AF4", "B5": "AFz",
    "B6": "Fz", "B7": "F2", "B8": "F4", "B9": "F6", "B10": "F8",
    "B11": "FT8", "B12": "FC6", "B13": "FC4", "B14": "FC2", "B15": "FCz",
    "B16": "Cz", "B17": "C2", "B18": "C4", "B19": "C6", "B20": "T8",
    "B21": "TP8", "B22": "CP6", "B23": "CP4", "B24": "CP2", "B25": "P2",
    "B26": "P4", "B27": "P6", "B28": "P8", "B29": "P10", "B30": "PO8",
    "B31": "PO4", "B32": "O2",
}

# Anwenden des offiziellen BioSemi-Mappings
raw_eeg.rename_channels(bios64_to_1020)

# BioSemi-Standardmontage
mont = mne.channels.make_standard_montage("biosemi64")
raw_eeg.set_montage(mont)

# Jetzt können die Sensoren geplottet werden
raw_eeg.plot_sensors(kind='topomap', show_names=True, sphere='auto')
# Out:
# Loading: c:\Users\hugoh\OneDrive\01 - Studium\MSc\00 - Module\SpaAohbp\eeg-bala-sharks\sanity_checks\..\data\sub-01_P1_raw.fif
# Opening raw data file c:\Users\hugoh\OneDrive\01 - Studium\MSc\00 - Module\SpaAohbp\eeg-bala-sharks\sanity_checks\..\data\sub-01_P1_raw.fif...
#     Range : 0 ... 7514111 =      0.000 ...  3669.000 secs
# Ready.
# Reading 0 ... 7514111  =      0.000 ...  3669.000 secs...
# ✅ Raw data loaded.
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).

# %%
import sys
from pathlib import Path
sys.path.insert(0, str((Path.cwd() / '..' / 'eeg_pipeline').resolve()))

import utils
from utils import load_raw

# --- Original Data ---
raw_orig = load_raw("../data/sub-01_P1_raw.fif")

# --- Re-referenced Data ---
raw_reref = load_raw("../data/sub-01_P1_raw_CAR.fif")

# --- Choose EEG Channels ---
eeg_chs = [ch for ch in raw_orig.ch_names if ch.startswith("1-A") or ch.startswith("1-B")]
raw_orig.pick_channels([c for c in eeg_chs if c == '1-B16'])
raw_reref.pick_channels([c for c in eeg_chs if c == '1-B16'])

# --- Scaling: e.g. ±100 µV, same for all channels ---
scaling = 1000e-6  # Volt

# --- Originalplot ---
raw_orig.plot(n_channels=len(eeg_chs), duration=60, scalings={'eeg': scaling}, title="Original P1")

# --- Re-referenced Plot ---
raw_reref.plot(n_channels=len(eeg_chs), duration=60, scalings={'eeg': scaling}, title="Re-referenced P1")
# Out:
# Opening raw data file ../data/sub-01_P1_raw.fif...
#     Range : 0 ... 7514111 =      0.000 ...  3669.000 secs
# Ready.
# Reading 0 ... 7514111  =      0.000 ...  3669.000 secs...
# Opening raw data file ../data/sub-01_P1_raw_CAR.fif...
# C:\Users\hugoh\OneDrive\01 - Studium\MSc\00 - Module\SpaAohbp\eeg-bala-sharks\eeg_pipeline\utils.py:10: RuntimeWarning: This filename (../data/sub-01_P1_raw_CAR.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   return mne.io.read_raw_fif(filename, preload=preload)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 raw_orig = load_raw("../data/sub-01_P1_raw.fif")
#      11 # --- Re-referenced Data ---
# ---> 12 raw_reref = load_raw("../data/sub-01_P1_raw_CAR.fif")
#      14 # --- Choose EEG Channels ---
#      15 eeg_chs = [ch for ch in raw_orig.ch_names if ch.startswith("1-A") or ch.startswith("1-B")]
#
# File ~\OneDrive\01 - Studium\MSc\00 - Module\SpaAohbp\eeg-bala-sharks\eeg_pipeline\utils.py:10, in load_raw(filename, preload)
#       9 def load_raw(filename, preload=True):
# ---> 10     return mne.io.read_raw_fif(filename, preload=preload)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mne\io\fiff\raw.py:543, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     502 @fill_doc
#     503 def read_raw_fif(
#     504     fname, allow_maxshield=False, preload=False, on_split_missing="raise", verbose=None
#     505 ) -> Raw:
#     506     """Reader function for Raw FIF data.
#     507
#     508     Parameters
#    (...)    541     are updated accordingly.
#     542     """
# --> 543     return Raw(
#     544         fname=fname,
#     545         allow_maxshield=allow_maxshield,
#     546         preload=preload,
#     547         verbose=verbose,
#     548         on_split_missing=on_split_missing,
#     549     )
#
# File <decorator-gen-206>:12, in __init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mne\io\fiff\raw.py:103, in Raw.__init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#     101 next_fname = fname
#     102 while next_fname is not None:
# --> 103     raw, next_fname, buffer_size_sec = self._read_raw_file(
#     104         next_fname, allow_maxshield, preload, do_check_ext
#     105     )
#     106     do_check_ext = False
#     107     raws.append(raw)
#
# File <decorator-gen-207>:12, in _read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mne\io\fiff\raw.py:198, in Raw._read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#     196         check_fname(fname, "raw", endings)
#     197     # filename
# --> 198     fname = _check_fname(fname, "read", True, "fname")
#     199     whole_file = preload if fname.suffix == ".gz" else False
#     200 else:
#     201     # file-like
#
# File <decorator-gen-0>:12, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mne\utils\check.py:302, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#     300             raise PermissionError(f"{name} does not have read permissions: {fname}")
#     301 elif must_exist:
# --> 302     raise FileNotFoundError(f'{name} does not exist: "{fname}"')
#     304 return fname
#
# FileNotFoundError: fname does not exist: "c:\Users\hugoh\OneDrive\01 - Studium\MSc\00 - Module\SpaAohbp\eeg-bala-sharks\sanity_checks\..\data\sub-01_P1_raw_CAR.fif"
