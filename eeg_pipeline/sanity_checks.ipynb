# %%
import config
from sanity_check_02_re_reference import sanity_check_reref
from pathlib import Path

# Anpassung für Notebook in eeg_pipeline
config.OUTPUT_DIR = Path("../data").resolve()  # relativ zum Notebook-Ordner

sanity_check_reref('01')
# Out:
# === Sanity check for re-referenced data: Subject 01 ===
# Opening raw data file ..\data\sub_01_task-RPS_p1_ref_raw.fif...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 # Anpassung für Notebook in eeg_pipeline
#       6 config.OUTPUT_DIR = Path("../data")  # relativ zum Notebook-Ordner
# ----> 8 sanity_check_reref('01')
#
# File c:\Users\bk57s\Visual Studio Code\EEG_Bala Sharks\eeg_pipeline\sanity_check_02_re_reference.py:41, in sanity_check_reref(subject_id, compare_original)
#      36     file_orig = Path(config.OUTPUT_DIR) / f"sub-{subject_id}_task-RPS_raw.fif"
#      38 # -------------------------------
#      39 # Load raw data
#      40 # -------------------------------
# ---> 41 raw_p1 = mne.io.read_raw_fif(file_p1, preload=True)
#      42 raw_p2 = mne.io.read_raw_fif(file_p2, preload=True)
#      43 if compare_original:
#
# File c:\Users\bk57s\Visual Studio Code\EEG_Bala Sharks\venv\lib\site-packages\mne\io\fiff\raw.py:532, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     491 @fill_doc
#     492 def read_raw_fif(
#     493     fname, allow_maxshield=False, preload=False, on_split_missing="raise", verbose=None
#     494 ) -> Raw:
#     495     """Reader function for Raw FIF data.
#     496
#     497     Parameters
#    (...)
#     530     are updated accordingly.
#     531     """
# --> 532     return Raw(
#     533         fname=fname,
#     534         allow_maxshield=allow_maxshield,
#     535         preload=preload,
#     536         verbose=verbose,
#     537         on_split_missing=on_split_missing,
#     538     )
#
# File <decorator-gen-203>:12, in __init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#
# File c:\Users\bk57s\Visual Studio Code\EEG_Bala Sharks\venv\lib\site-packages\mne\io\fiff\raw.py:100, in Raw.__init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#      98 next_fname = fname
#      99 while next_fname is not None:
# --> 100     raw, next_fname, buffer_size_sec = self._read_raw_file(
#     101         next_fname, allow_maxshield, preload, do_check_ext
#     102     )
#     103     do_check_ext = False
#     104     raws.append(raw)
#
# File <decorator-gen-204>:12, in _read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#
# File c:\Users\bk57s\Visual Studio Code\EEG_Bala Sharks\venv\lib\site-packages\mne\io\fiff\raw.py:182, in Raw._read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#     180     check_fname(fname, "raw", endings)
#     181 # filename
# --> 182 fname = str(_check_fname(fname, "read", True, "fname"))
#     183 ext = os.path.splitext(fname)[1].lower()
#     184 whole_file = preload if ".gz" in ext else False
#
# File <decorator-gen-0>:12, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#
# File c:\Users\bk57s\Visual Studio Code\EEG_Bala Sharks\venv\lib\site-packages\mne\utils\check.py:274, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#     272             raise PermissionError(f"{name} does not have read permissions: {fname}")
#     273 elif must_exist:
# --> 274     raise FileNotFoundError(f'{name} does not exist: "{fname}"')
#     276 return fname
#
# FileNotFoundError: fname does not exist: "c:\Users\bk57s\Visual Studio Code\EEG_Bala Sharks\eeg_pipeline\..\data\sub_01_task-RPS_p1_ref_raw.fif"
